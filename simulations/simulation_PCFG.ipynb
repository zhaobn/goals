# %%
from itertools import product

# %%
productions = [
  ['S', ['and(S,S)', 'A']], # allow conjunctions
  ['A', ['one(B)', 'two(B)', 'three(B)', # location symmetry, fix one feature (location agnostic, compare feature)
         'two(E)', 'three(E)', # location symetry, feature symmetry (location agnostic, feature agnostic)
         'two(F,E)', 'three(F,E)', # location symmetry, multiple feature symetry (location agnostic, feature agnostic)
         'one(B,C)', 'two(B,D)', # feature in location, specify feature (location given, feature compare)
         'two(E,D)'# give location, feature symmetry (location given, feature agnostic)
         ]],
  ['B', ['square', 'circle', 'triangle', 'low', 'medium', 'high', 'striped', 'plain']], # features
  ['C', ['(0)', '(1)', '(2)']], # locations
  ['D', ['(0,1)', '(0,2)', '(1,2)']], # diad locations
  ['E', ['same','unique']], # relation,
  ['F', ['1','2','3']], # number of features to compare
]

# %%
def generate_all_programs(productions, start_symbol='S', max_depth=3):
    """
    Generate all possible programs from a PCFG up to a specified depth.
    
    Args:
        productions: List of production rules in format [lhs, [rhs1, rhs2, ...]]
        start_symbol: Starting non-terminal symbol
        max_depth: Maximum depth of derivation tree
        
    Returns:
        set: All possible programs up to max_depth
    """
    def expand(symbol, depth):
        '''Take a symbol, and expand.'''
        # stop the search if max depth reached
        if depth > max_depth:
            return set()
            
        # If symbol is terminal (not found as LHS in any production)
        if not any(p[0] == symbol for p in productions):
            return {symbol}
            
        # Find all productions for this symbol
        results = set()
        for lhs, rhs_list in productions:
            if lhs == symbol:
                for rhs in rhs_list:
                    # Handle compound expressions like 'and(S,S)' or 'one(B)'
                    if '(' in rhs:
                        # Split into function and arguments
                        func, args = rhs.split('(')
                        args = args[:-1]  # remove closing parenthesis
                        arg_symbols = args.split(',')
                        
                        # Recursively expand each argument
                        arg_expansions = [expand(arg.strip(), depth + 1) for arg in arg_symbols]
                        
                        # Generate all combinations of argument expansions
                        for arg_combo in product(*arg_expansions):
                            results.add(f"{func}({','.join(arg_combo)})")
                    else:
                        # Direct expansion for simple rules
                        expansions = expand(rhs, depth + 1)
                        results.update(expansions)
                        
        return results

    return expand(start_symbol, 0)

# Example usage:
programs = generate_all_programs(productions, max_depth=5)

# %%
# Out:
# {'and(and(two(same,(0,2)),two(low)),and(two(same,(0,2)),three(low)))',
#  'and(and(three(unique),one(high)),and(one(circle,(2)),two(square)))',
#  'and(and(two(1,same),two(high,(1,2))),and(one(high,(2)),one(low,(1))))',
#  'and(and(one(medium,(0)),one(triangle)),and(one(plain,(2)),two(medium,(0,2))))',
#  'and(and(one(triangle),two(2,unique)),and(two(high),one(low)))',
#  'and(and(two(circle),one(triangle,(1))),and(two(1,same),one(high,(2))))',
#  'and(and(one(medium),two(square)),and(three(medium),two(low,(0,1))))',
#  'and(and(one(plain,(2)),one(triangle)),and(two(2,unique),one(high)))',
#  'and(and(two(square,(0,1)),two(triangle,(1,2))),and(three(1,same),two(medium,(1,2))))',
#  'and(and(one(circle,(0)),one(striped,(2))),and(two(triangle,(0,2)),two(same,(1,2))))',
#  'and(and(two(unique,(0,2)),two(unique)),and(three(circle),two(striped,(0,2))))',
#  'and(and(one(high,(0)),two(same,(1,2))),and(two(square,(0,1)),one(high)))',
#  'and(and(three(same),two(2,unique)),and(two(plain,(0,2)),three(1,same)))',
#  'and(and(one(circle,(1)),one(plain,(0))),and(two(circle,(1,2)),one(low,(2))))',
#  'and(and(one(plain,(0)),two(2,same)),and(two(plain,(0,2)),three(3,unique)))',
#  'and(and(two(1,unique),one(circle,(1))),and(three(unique),two(triangle)))',
#  'and(and(two(high,(1,2)),one(triangle,(0))),and(two(low,(0,2)),one(striped)))',
#  'and(and(two(circle,(0,2)),two(unique,(0,1))),and(one(low,(1)),one(circle,(1))))',
#  'and(and(three(3,same),two(unique,(1,2))),and(one(plain,(2)),one(medium,(1))))',
#  'and(and(one(medium,(1)),one(square,(2))),and(two(triangle,(0,1)),two(circle,(0,1))))',
#  'and(and(one(plain,(0)),one(high)),and(one(triangle,(2)),two(striped,(1,2))))',
#  'and(and(two(triangle,(0,2)),two(triangle)),and(three(medium),two(medium)))',
#  'and(and(three(circle),one(triangle)),and(one(medium,(0)),one(medium,(2))))',
#  'and(and(one(striped,(1)),one(striped,(1))),and(one(triangle,(1)),two(striped,(0,1))))',
#  'and(and(two(low),two(high,(1,2))),and(one(triangle),one(striped,(0))))',
#  'and(and(two(square,(1,2)),one(circle,(1))),and(one(high),three(2,unique)))',
#  'and(and(three(high),two(triangle,(0,2))),and(one(triangle,(2)),one(circle,(1))))',
#  'and(and(three(striped),two(2,same)),and(one(medium),two(plain)))',
#  'and(and(two(3,unique),three(same)),and(three(2,unique),two(high,(1,2))))',
#  'and(and(two(medium,(0,2)),two(striped,(1,2))),and(two(triangle,(0,1)),one(plain)))',
#  'and(and(three(high),one(high)),and(two(3,unique),two(1,unique)))',
#  'and(and(two(circle,(1,2)),two(low,(0,2))),and(two(low,(1,2)),two(square)))',
#  'and(and(two(striped,(1,2)),one(circle,(1))),and(two(medium,(1,2)),two(same,(0,1))))',
#  'and(and(two(low,(1,2)),two(medium)),and(two(low,(0,2)),one(plain)))',
#  'and(and(two(1,unique),one(medium,(2))),and(two(medium,(1,2)),one(plain,(1))))',
#  'and(and(one(medium,(0)),three(2,same)),and(three(square),one(square,(1))))',
#  'and(and(three(same),two(high)),and(one(low,(1)),three(2,same)))',
#  'and(and(two(3,unique),three(2,unique)),and(one(triangle),two(triangle)))',
#  'and(and(three(high),three(high)),and(one(striped,(1)),two(striped,(0,1))))',
#  'and(and(two(medium,(0,1)),one(striped,(2))),and(one(circle,(2)),two(high,(0,1))))',
#  'and(and(two(plain,(0,2)),two(circle,(1,2))),and(one(plain,(0)),two(circle)))',
#  'and(and(two(plain,(0,2)),three(plain)),and(two(high,(0,1)),two(unique,(1,2))))',
#  'and(and(two(plain,(1,2)),one(striped,(2))),and(two(2,unique),two(high,(0,2))))',
#  'and(and(one(high,(1)),three(circle)),and(two(medium,(0,2)),two(high)))',
#  'and(and(two(plain,(1,2)),three(1,same)),and(one(square,(0)),two(low,(0,2))))',
#  'and(and(three(circle),one(triangle,(0))),and(three(plain),one(plain,(2))))',
#  'and(and(two(triangle,(0,1)),three(1,unique)),and(one(circle,(0)),one(low)))',
#  'and(and(two(unique),two(high)),and(two(circle,(0,1)),two(unique,(1,2))))',
#  'and(and(two(striped,(0,2)),one(high,(0))),and(one(low,(1)),one(high,(1))))',
#  'and(and(one(square,(2)),two(1,same)),and(one(square,(2)),one(high,(2))))',
#  'and(and(two(triangle),two(triangle,(0,1))),and(one(low,(2)),one(high,(1))))',
#  'and(and(one(square,(0)),two(1,unique)),and(two(striped,(0,2)),two(square,(1,2))))',
#  'and(and(two(1,same),two(medium)),and(one(plain,(0)),three(same)))',
#  'and(and(two(same),two(high,(0,1))),and(one(square,(0)),two(circle)))',
#  'and(and(two(3,same),two(2,same)),and(one(high,(0)),one(striped,(2))))',
#  'and(and(two(plain,(0,1)),one(triangle,(0))),and(three(1,same),three(same)))',
#  'and(and(one(plain),three(2,unique)),and(two(unique,(1,2)),two(triangle,(1,2))))',
#  'and(and(one(low,(0)),two(low,(1,2))),and(two(unique),one(plain,(2))))',
#  'and(and(two(high),one(square,(1))),and(two(square),two(striped)))',
#  'and(and(three(unique),two(medium,(0,1))),and(one(high,(2)),two(triangle)))',
#  'and(and(two(striped,(1,2)),two(square,(1,2))),and(two(plain,(0,2)),two(striped,(1,2))))',
#  'and(and(three(2,same),two(square,(0,1))),and(one(low,(0)),three(1,same)))',
#  'and(and(two(plain,(0,2)),one(striped,(1))),and(three(plain),two(2,unique)))',
#  'and(and(one(high,(0)),two(unique,(1,2))),and(one(square,(2)),one(low,(0))))',
#  'and(and(two(triangle),two(low,(0,2))),and(two(striped,(1,2)),one(plain,(2))))',
#  'and(and(two(striped,(0,1)),two(same)),and(two(low,(1,2)),one(circle,(2))))',
#  'and(and(one(triangle),two(unique)),and(two(unique,(0,1)),two(low,(1,2))))',
#  'and(and(one(high,(0)),three(striped)),and(two(square,(0,2)),two(low,(1,2))))',
#  'and(and(one(square,(2)),two(same,(0,2))),and(one(plain),one(striped,(2))))',
#  'and(and(three(triangle),one(striped,(0))),and(two(high,(1,2)),two(circle,(0,2))))',
#  'and(and(one(square,(0)),one(plain,(1))),and(three(plain),two(triangle)))',
#  'and(and(two(medium,(0,2)),three(high)),and(one(circle,(1)),two(high,(1,2))))',
#  'and(and(two(striped,(0,2)),three(triangle)),and(three(3,same),two(square,(0,2))))',
#  'and(and(one(medium,(2)),two(triangle,(1,2))),and(two(striped,(0,1)),three(circle)))',
#  'and(and(three(circle),one(square,(0))),and(two(high),three(circle)))',
#  'and(and(one(circle,(0)),two(striped,(1,2))),and(three(medium),two(same)))',
#  'and(and(one(low,(1)),one(square,(1))),and(two(medium,(0,2)),one(striped,(2))))',
#  'and(and(two(triangle,(0,2)),three(low)),and(two(2,same),one(low)))',
#  'and(and(one(medium,(2)),two(striped,(0,2))),and(one(plain,(0)),two(3,same)))',
#  'and(and(two(low),one(medium,(2))),and(two(circle),one(triangle)))',
#  'and(and(two(high),two(medium,(0,1))),and(two(3,unique),three(striped)))',
#  'and(and(three(square),two(2,same)),and(one(circle,(0)),one(striped,(1))))',
#  'and(and(one(high,(2)),three(plain)),and(two(unique),one(medium,(0))))',
#  'and(and(three(plain),two(medium,(1,2))),and(two(high),two(circle,(1,2))))',
#  'and(and(three(2,unique),one(circle,(1))),and(two(circle),three(low)))',
#  'and(and(one(circle),two(medium,(0,2))),and(one(striped,(2)),two(1,unique)))',
#  'and(and(one(circle,(0)),one(high,(1))),and(one(medium,(2)),one(plain)))',
#  'and(and(two(triangle),three(same)),and(one(striped,(1)),two(2,unique)))',
#  'and(and(two(circle,(0,2)),two(low,(0,2))),and(one(plain,(1)),two(triangle,(0,2))))',
#  'and(and(two(medium,(1,2)),two(square)),and(one(high,(2)),two(striped,(0,1))))',
#  'and(and(two(2,same),two(medium,(0,1))),and(two(triangle),one(circle,(0))))',
#  'and(and(one(medium,(1)),one(low,(1))),and(two(high,(1,2)),two(high,(0,1))))',
#  'and(and(two(unique),two(circle)),and(one(high,(0)),two(medium,(0,2))))',
#  'and(and(two(circle,(0,2)),one(medium,(1))),and(one(low,(1)),one(high,(0))))',
#  'and(and(one(triangle,(0)),two(1,unique)),and(two(same,(0,2)),one(plain)))',
#  'and(and(one(high),one(triangle,(2))),and(two(medium,(1,2)),one(high,(2))))',
#  'and(and(two(unique,(1,2)),one(medium,(1))),and(three(high),one(high)))',
#  'and(and(one(circle),three(3,unique)),and(two(1,unique),one(circle)))',
#  'and(and(two(striped,(0,2)),two(striped,(0,1))),and(one(plain),two(3,same)))',
#  'and(and(three(3,same),two(low,(0,1))),and(one(triangle),two(plain)))',
#  'and(and(three(2,unique),one(plain,(0))),and(one(circle,(2)),two(medium)))',
#  'and(and(two(same,(0,1)),two(unique,(0,1))),and(one(plain,(2)),two(1,same)))',
#  'and(and(two(same,(1,2)),two(low,(0,2))),and(three(low),three(same)))',
#  'and(and(one(medium),two(medium,(0,2))),and(one(striped),one(high)))',
#  'and(and(three(striped),three(unique)),and(two(high,(1,2)),one(triangle,(0))))',
#  'and(and(three(same),one(medium,(0))),and(three(same),two(circle,(0,2))))',
#  'and(and(one(square),two(1,unique)),and(three(1,unique),three(high)))',
#  'and(and(two(circle,(0,1)),one(high,(2))),and(two(same,(1,2)),two(unique)))',
#  'and(and(two(circle,(0,2)),two(high,(0,1))),and(one(square),two(unique,(0,2))))',
#  'and(and(two(square),three(circle)),and(two(square,(0,1)),two(circle,(1,2))))',
#  'and(and(two(striped,(0,2)),two(triangle)),and(one(high,(0)),one(circle,(2))))',
#  'and(and(one(medium),two(same,(0,2))),and(two(unique),one(low)))',
#  'and(and(two(unique),two(square,(0,1))),and(two(triangle,(1,2)),two(1,unique)))',
#  'and(and(two(medium,(0,1)),two(high,(0,2))),and(one(triangle),two(medium,(1,2))))',
#  'and(and(one(low),one(medium)),and(one(circle,(2)),two(2,same)))',
#  'and(and(two(circle,(1,2)),three(same)),and(two(circle,(0,2)),two(same,(1,2))))',
#  'and(and(one(high,(0)),three(striped)),and(two(same,(0,1)),two(striped,(0,1))))',
#  'and(and(two(striped,(1,2)),one(square,(1))),and(three(medium),one(striped)))',
#  'and(and(one(square,(0)),one(high,(2))),and(two(low,(0,2)),three(striped)))',
#  'and(and(two(plain,(1,2)),three(low)),and(two(medium,(0,2)),three(high)))',
#  'and(and(one(triangle,(2)),two(medium)),and(one(high,(2)),two(low)))',
#  'and(and(one(triangle,(1)),two(high,(0,2))),and(one(square,(1)),two(low,(0,1))))',
#  'and(and(two(low,(1,2)),three(circle)),and(three(high),one(striped,(2))))',
#  'and(and(two(unique,(0,2)),one(striped,(0))),and(one(square,(0)),one(high,(1))))',
#  'and(and(one(low,(1)),one(circle)),and(two(striped,(1,2)),two(square,(0,2))))',
#  'and(and(two(plain),two(triangle,(1,2))),and(two(3,same),three(2,unique)))',
#  'and(and(two(3,same),one(circle,(0))),and(one(circle),two(2,same)))',
#  'and(two(striped,(0,2)),and(one(high),two(high,(0,2))))',
#  'and(and(two(high,(0,2)),three(high)),and(one(striped,(0)),two(triangle)))',
#  'and(and(two(plain),one(high,(0))),and(one(high,(1)),one(high,(0))))',
#  'and(and(three(1,same),two(striped,(0,2))),and(two(medium,(0,1)),two(same,(1,2))))',
#  'and(and(two(medium,(0,2)),one(circle,(1))),and(two(same,(0,1)),one(plain,(1))))',
#  'and(and(one(triangle,(1)),one(plain,(1))),and(two(low,(1,2)),one(high,(1))))',
#  'and(and(three(medium),two(same,(0,1))),two(1,unique))',
#  'and(and(one(circle),two(2,same)),and(one(plain),one(circle,(1))))',
#  'and(and(two(circle),three(same)),and(three(same),three(triangle)))',
#  'and(and(one(medium,(0)),three(3,unique)),and(two(plain,(0,1)),two(triangle,(0,2))))',
#  'and(and(one(high,(1)),two(same)),and(two(same),one(medium,(1))))',
#  'and(and(three(3,unique),one(square)),and(two(1,unique),two(square)))',
#  'and(and(two(high,(0,2)),two(circle)),and(one(low,(1)),two(low,(1,2))))',
#  'and(and(one(plain,(0)),two(square,(1,2))),and(two(same,(0,1)),two(high,(1,2))))',
#  'and(and(three(square),two(high,(1,2))),and(two(circle,(0,2)),one(medium)))',
#  'and(and(three(circle),three(3,unique)),and(two(unique,(0,1)),one(circle,(2))))',
#  'and(and(two(same,(1,2)),two(square,(0,1))),and(three(3,unique),one(triangle)))',
#  'and(and(one(striped,(0)),two(medium,(0,2))),and(two(low,(0,1)),two(high,(0,2))))',
#  'and(and(two(circle,(0,2)),two(low)),and(two(3,unique),two(square,(0,1))))',
#  'and(and(two(same,(0,1)),two(same,(0,2))),and(three(same),two(high,(0,1))))',
#  'and(and(two(plain,(0,1)),one(low,(2))),and(one(medium,(0)),two(unique,(1,2))))',
#  'and(and(one(circle,(1)),two(medium,(1,2))),and(two(circle,(0,2)),one(square,(0))))',
#  'and(and(two(medium),one(low,(0))),and(two(2,same),two(circle,(0,1))))',
#  'and(and(one(circle),two(circle,(0,1))),and(two(triangle),one(medium,(2))))',
#  'and(and(one(medium,(1)),one(plain,(1))),and(two(high,(1,2)),one(medium)))',
#  'and(and(three(1,unique),two(medium,(0,2))),and(one(square),one(high,(1))))',
#  'and(and(two(1,same),two(circle,(0,1))),and(three(square),three(striped)))',
#  'and(and(one(square,(2)),one(circle,(1))),and(two(square,(0,1)),one(square)))',
#  'and(and(one(plain,(0)),one(plain,(0))),and(one(square,(2)),two(low,(0,2))))',
#  'and(and(one(circle,(2)),one(striped)),and(two(circle,(0,2)),one(striped,(2))))',
#  'and(and(three(2,unique),two(square)),and(two(medium,(1,2)),two(3,same)))',
#  'and(and(two(3,same),three(plain)),and(two(circle,(0,2)),two(striped)))',
#  'and(and(two(medium),one(circle,(0))),and(three(same),two(square,(1,2))))',
#  'and(and(one(striped),two(plain,(0,2))),and(two(2,unique),one(triangle,(0))))',
#  'and(and(one(medium,(1)),three(2,same)),and(two(striped),one(plain,(2))))',
#  'and(and(two(medium,(0,1)),two(striped)),and(one(circle,(0)),one(square,(1))))',
#  'and(and(two(high,(0,1)),two(high,(1,2))),and(two(triangle,(0,1)),three(2,unique)))',
#  'and(and(two(striped,(1,2)),two(same,(0,1))),and(two(plain,(0,1)),two(circle,(1,2))))',
#  'and(and(one(triangle),one(circle,(0))),and(two(unique,(0,2)),three(medium)))',
#  'and(and(three(2,same),one(plain)),and(three(circle),one(triangle,(0))))',
#  'and(and(three(triangle),one(triangle,(0))),and(one(striped,(1)),one(square,(2))))',
#  'and(and(one(plain,(1)),one(high,(1))),and(one(plain,(1)),one(medium,(1))))',
#  'and(and(three(medium),two(striped,(1,2))),and(two(high),two(square)))',
#  'and(and(one(striped,(2)),one(striped)),and(two(medium,(0,2)),one(high)))',
#  'and(and(two(1,same),two(2,same)),and(two(striped,(0,1)),one(square,(1))))',
#  'and(and(three(low),two(low,(0,2))),and(one(medium,(1)),one(square,(2))))',
#  'and(and(three(triangle),one(high,(1))),and(two(2,same),three(plain)))',
#  'and(and(two(square),two(high)),and(three(square),two(striped)))',
#  'and(and(one(medium,(0)),one(square)),and(one(medium,(1)),two(2,unique)))',
#  'and(and(three(medium),one(striped)),and(three(same),three(3,same)))',
#  'and(and(two(striped,(1,2)),one(medium,(2))),two(plain,(0,2)))',
#  'and(and(two(triangle,(0,1)),one(plain,(0))),and(two(2,same),two(plain,(0,1))))',
#  'and(and(one(striped,(1)),two(low,(0,2))),and(two(low,(1,2)),one(medium)))',
#  'and(and(two(striped),two(high,(0,1))),and(two(striped,(0,1)),two(low)))',
#  'and(and(three(unique),three(2,same)),and(one(medium),two(medium,(0,1))))',
#  'and(and(one(triangle,(2)),one(low,(0))),and(three(plain),one(circle,(0))))',
#  'and(and(one(circle,(1)),one(circle,(1))),and(two(medium,(0,1)),two(same,(0,1))))',
#  'and(and(one(striped),three(striped)),and(one(high,(2)),three(circle)))',
#  'and(and(two(triangle,(1,2)),three(same)),and(one(striped,(1)),three(1,same)))',
#  'and(and(two(same,(0,2)),two(1,same)),and(two(high,(1,2)),three(striped)))',
#  'and(and(two(high,(1,2)),one(square,(1))),and(three(triangle),two(striped,(0,2))))',
#  'and(and(two(low,(1,2)),one(square,(0))),and(two(plain,(1,2)),one(plain,(1))))',
#  'and(and(one(circle,(2)),two(medium,(0,1))),and(one(low,(0)),three(triangle)))',
#  'and(two(same,(0,1)),and(one(square,(2)),one(high,(1))))',
#  'and(and(two(unique),two(high,(0,2))),and(two(unique,(1,2)),one(plain,(2))))',
#  'and(and(one(plain,(0)),two(1,unique)),and(two(unique,(0,2)),two(same,(0,1))))',
#  'and(one(low),and(one(square),two(plain)))',
#  'and(and(one(striped,(2)),one(circle,(2))),and(three(square),one(circle,(0))))',
#  'and(and(two(2,unique),three(1,unique)),and(three(1,same),two(same,(0,1))))',
#  'and(and(three(3,unique),one(striped)),and(three(circle),two(2,unique)))',
#  'and(and(one(striped,(0)),two(high,(0,1))),and(two(3,same),one(circle,(2))))',
#  'and(and(one(medium),one(square,(2))),and(two(plain,(0,1)),one(plain)))',
#  'and(and(two(same,(0,1)),three(2,same)),and(two(unique,(1,2)),two(striped,(1,2))))',
#  'and(and(two(unique,(0,2)),one(plain,(1))),and(one(high,(1)),one(high,(0))))',
#  'and(and(two(low,(0,1)),two(square,(1,2))),and(three(plain),two(low)))',
#  'and(and(three(triangle),two(plain)),and(two(triangle,(0,1)),two(1,same)))',
#  'and(and(two(circle),one(plain,(1))),and(two(circle),two(triangle,(1,2))))',
#  'and(and(two(square),one(square,(0))),and(one(medium,(0)),one(high,(2))))',
#  'and(and(one(triangle),two(3,unique)),and(three(same),two(same,(0,1))))',
#  'and(and(one(triangle,(2)),two(striped,(0,1))),and(two(square,(0,2)),two(low)))',
#  'and(and(three(high),one(plain,(0))),and(two(medium,(1,2)),one(medium)))',
#  'and(and(three(high),one(high)),and(three(3,same),two(square,(0,1))))',
#  'and(and(two(square,(0,2)),three(1,same)),and(one(medium,(0)),one(low,(1))))',
#  'and(and(two(square),three(same)),and(one(striped,(0)),one(high)))',
#  'and(and(two(same,(0,2)),two(triangle)),and(two(medium),two(square,(1,2))))',
#  'and(and(one(medium,(2)),one(striped)),and(one(low),two(circle,(1,2))))',
#  'and(and(two(high,(0,2)),one(striped)),and(two(plain,(0,1)),two(circle,(0,2))))',
#  'and(and(one(square,(2)),two(3,unique)),and(three(low),two(striped)))',
#  'and(and(one(high),two(striped,(0,1))),and(one(triangle,(2)),two(low)))',
#  'and(and(three(2,same),three(high)),and(two(medium,(1,2)),two(3,unique)))',
#  'and(and(two(low,(0,2)),two(striped,(0,2))),and(two(high,(1,2)),three(striped)))',
#  'and(and(one(triangle,(2)),two(high,(0,1))),and(two(same,(0,1)),one(square,(1))))',
#  'and(and(one(plain,(0)),two(square,(1,2))),and(two(1,same),three(circle)))',
#  'and(and(one(low,(0)),two(unique,(0,2))),and(three(plain),two(triangle)))',
#  'and(and(one(medium,(0)),three(2,same)),and(three(low),two(circle,(1,2))))',
#  'and(and(one(circle,(0)),three(2,same)),and(two(3,same),one(striped)))',
#  'and(and(one(high,(1)),two(plain)),and(two(low,(0,2)),three(1,same)))',
#  'and(and(one(high,(0)),two(high)),and(one(high,(2)),three(striped)))',
#  'and(and(three(1,unique),three(triangle)),and(one(low,(1)),one(high,(1))))',
#  'and(two(same,(0,2)),and(two(circle,(1,2)),one(low)))',
#  'and(and(two(triangle),two(striped,(1,2))),and(one(low),one(circle,(1))))',
#  'and(and(two(high),two(triangle,(1,2))),and(one(triangle,(2)),one(plain,(1))))',
#  'and(and(one(triangle),one(medium,(2))),and(three(unique),two(unique)))',
#  'and(and(two(triangle,(0,1)),three(1,unique)),and(two(circle,(0,2)),two(unique)))',
#  'and(and(two(2,same),one(triangle,(0))),and(three(2,same),one(triangle)))',
#  'and(and(one(high,(2)),two(1,same)),and(three(3,unique),one(square,(2))))',
#  'and(and(one(triangle,(0)),two(unique,(0,1))),and(two(same,(0,1)),two(circle)))',
#  'and(one(plain,(1)),and(one(circle,(1)),one(plain,(2))))',
#  'and(and(two(triangle,(0,2)),two(unique,(1,2))),and(one(low),one(triangle,(2))))',
#  'and(and(one(high,(1)),two(high,(0,2))),and(two(plain,(0,2)),three(square)))',
#  'and(and(three(1,same),one(medium,(1))),and(two(low,(0,1)),one(circle,(0))))',
#  'and(and(two(high),two(3,same)),and(one(triangle,(2)),one(high)))',
#  'and(and(two(unique,(0,2)),two(1,same)),and(two(medium,(0,1)),one(triangle)))',
#  'and(and(two(medium,(0,2)),one(square,(2))),and(two(striped,(0,2)),one(plain)))',
#  'and(and(one(circle,(1)),one(triangle,(2))),and(two(high),two(medium,(0,1))))',
#  'and(and(two(low,(0,2)),one(plain,(2))),and(two(2,same),one(circle)))',
#  'and(and(two(low,(0,2)),one(triangle,(0))),and(one(triangle,(0)),two(medium,(0,1))))',
#  'and(and(two(high,(0,1)),two(triangle,(1,2))),and(one(striped,(0)),one(striped,(1))))',
#  'and(and(two(high,(1,2)),one(low)),and(two(unique,(1,2)),two(low,(0,2))))',
#  'and(and(three(plain),two(low,(0,1))),and(one(plain),two(unique,(1,2))))',
#  'and(and(three(plain),two(plain)),and(one(circle,(2)),one(low,(1))))',
#  'and(and(two(circle),two(triangle,(0,1))),and(three(striped),two(triangle,(0,1))))',
#  'and(and(one(medium,(1)),one(medium)),and(one(low,(2)),three(plain)))',
#  'and(and(one(high,(2)),three(plain)),and(three(1,unique),one(medium,(0))))',
#  'and(and(two(2,unique),one(square,(0))),and(two(1,unique),one(high,(0))))',
#  'and(and(one(plain,(0)),two(striped,(0,2))),and(three(2,unique),three(unique)))',
#  'and(and(one(plain,(0)),one(striped,(1))),and(two(2,same),one(square,(1))))',
#  'and(and(two(circle,(1,2)),two(medium,(1,2))),and(one(circle),two(circle,(0,2))))',
#  'and(and(three(plain),two(striped,(0,1))),and(one(plain),one(circle)))',
#  'and(and(one(triangle,(2)),two(circle,(1,2))),and(two(high,(0,2)),two(same)))',
#  'and(and(two(low,(0,1)),two(striped,(1,2))),and(two(low,(0,1)),two(striped,(0,1))))',
#  'and(and(three(square),one(high,(1))),and(two(triangle,(0,1)),one(striped,(2))))',
#  'and(and(two(triangle,(0,1)),one(circle)),and(two(circle,(0,2)),two(low,(1,2))))',
#  'and(and(three(medium),two(same,(0,1))),and(two(high,(0,2)),three(3,same)))',
#  'and(and(one(square),three(3,same)),and(two(medium),two(same)))',
#  'and(and(one(medium),two(low)),and(two(same,(0,1)),one(low,(1))))',
#  'and(and(three(striped),two(3,unique)),and(one(plain,(0)),three(3,unique)))',
#  'and(and(two(circle,(1,2)),one(high,(2))),and(one(plain),one(striped)))',
#  'and(and(two(plain),three(square)),and(one(plain,(1)),one(plain,(2))))',
#  'and(and(one(medium,(0)),two(square)),and(two(same),two(plain,(1,2))))',
#  'and(and(three(low),two(same)),and(one(medium,(0)),three(medium)))',
#  'and(and(three(same),one(triangle)),and(two(square,(1,2)),two(striped)))',
#  'and(and(one(striped,(2)),one(square,(0))),and(two(low,(0,2)),three(unique)))',
#  'and(and(three(2,same),two(medium)),and(two(striped,(1,2)),one(triangle,(0))))',
#  'and(and(three(unique),two(unique,(1,2))),and(three(2,unique),two(3,same)))',
#  'and(and(two(triangle,(0,2)),two(1,same)),and(two(same,(0,2)),two(striped,(0,2))))',
#  'and(and(three(square),three(triangle)),and(two(low),two(triangle,(0,1))))',
#  'and(and(two(striped,(0,1)),one(triangle)),and(three(unique),three(medium)))',
#  'and(and(one(circle),one(high,(1))),and(one(plain,(1)),one(high,(1))))',
#  'and(and(one(triangle,(0)),one(striped,(2))),and(one(plain,(0)),three(3,same)))',
#  'and(and(three(striped),two(square,(0,2))),and(two(same,(0,1)),one(square)))',
#  'and(and(one(plain),two(high,(0,2))),and(two(same,(0,2)),one(square,(1))))',
#  'and(and(one(triangle,(1)),one(plain)),and(one(striped,(2)),two(1,unique)))',
#  'and(and(two(low,(1,2)),two(medium,(0,1))),and(three(striped),one(high)))',
#  'and(and(three(circle),one(striped)),and(one(plain,(2)),two(high)))',
#  'and(and(one(square,(1)),two(triangle,(1,2))),and(one(medium,(1)),two(unique,(1,2))))',
#  'and(and(two(striped),two(striped,(0,2))),one(square,(2)))',
#  'and(and(one(plain),one(medium,(2))),and(one(medium),two(plain,(0,2))))',
#  'and(and(two(2,unique),three(triangle)),and(one(high,(1)),one(medium)))',
#  'and(and(two(same,(1,2)),three(circle)),and(three(3,unique),one(triangle,(1))))',
#  'and(and(two(high),two(circle,(0,1))),and(two(striped,(0,1)),three(medium)))',
#  'and(and(one(striped,(1)),two(striped)),and(two(high,(1,2)),one(medium)))',
#  'and(and(two(striped),one(square,(2))),and(three(circle),two(low,(1,2))))',
#  'and(and(two(1,unique),one(high,(1))),and(one(striped,(0)),two(high,(0,2))))',
#  'and(and(two(high,(0,1)),two(same)),and(one(striped,(2)),three(same)))',
#  'and(and(two(plain,(0,1)),two(unique,(0,1))),and(one(striped,(0)),three(low)))',
#  'and(and(one(medium,(2)),two(square,(1,2))),and(three(same),three(square)))',
#  'and(and(two(square,(0,1)),one(plain,(1))),and(two(unique,(0,2)),two(striped)))',
#  'and(and(one(low,(0)),two(medium)),and(two(square,(0,2)),two(plain,(1,2))))',
#  'and(and(two(unique,(0,2)),two(plain,(0,1))),and(three(circle),one(triangle,(1))))',
#  'and(and(two(striped,(1,2)),one(high,(2))),and(one(circle,(1)),three(1,same)))',
#  'and(and(two(unique,(0,2)),three(unique)),and(two(unique),three(striped)))',
#  'and(and(two(square),one(low,(2))),and(three(1,same),two(circle,(0,1))))',
#  'and(and(two(medium,(0,1)),two(striped,(0,2))),and(two(striped,(0,2)),three(square)))',
#  'and(and(one(square,(1)),three(3,same)),and(two(square),two(square,(1,2))))',
#  'and(and(one(medium),one(striped)),and(two(square,(0,1)),three(2,same)))',
#  'and(and(one(plain,(0)),one(high,(0))),and(two(high),two(circle,(0,2))))',
#  'and(and(three(square),two(plain)),and(one(circle,(1)),one(circle)))',
#  'and(and(three(striped),one(high,(2))),and(three(2,same),two(plain,(1,2))))',
#  'and(and(two(1,same),one(square,(2))),and(two(high),three(1,unique)))',
#  'and(and(two(same,(1,2)),two(striped)),and(one(low,(0)),two(1,same)))',
#  'and(and(two(triangle,(0,2)),one(triangle,(0))),and(three(medium),two(1,unique)))',
#  'and(and(one(square,(0)),one(striped,(2))),and(one(plain,(1)),two(high,(1,2))))',
#  'and(and(two(circle,(0,1)),two(plain,(0,1))),and(three(plain),one(triangle,(2))))',
#  'and(and(two(low,(0,1)),two(1,unique)),and(two(2,unique),one(triangle,(2))))',
#  'and(and(one(low),two(low,(0,2))),and(two(2,unique),one(medium)))',
#  'and(and(two(striped,(0,1)),three(same)),and(one(medium,(1)),one(triangle,(2))))',
#  'and(and(three(circle),one(medium,(2))),and(one(high,(2)),three(circle)))',
#  'and(and(two(low,(0,1)),two(1,same)),and(one(plain),two(unique)))',
#  'and(and(three(2,unique),two(unique,(0,2))),and(three(striped),one(square,(1))))',
#  'and(and(two(low,(0,1)),three(plain)),and(two(circle,(0,1)),three(high)))',
#  'and(and(two(triangle,(0,2)),three(1,same)),and(three(low),two(high,(0,2))))',
#  'and(and(two(3,same),three(triangle)),and(two(triangle,(0,2)),two(same,(0,1))))',
#  'and(and(one(circle,(1)),one(striped,(0))),and(two(circle),two(unique,(0,1))))',
#  'and(and(two(1,unique),one(triangle,(1))),and(one(square,(0)),two(same,(0,2))))',
#  'and(and(two(striped,(0,2)),two(high,(1,2))),and(two(striped,(1,2)),one(square,(1))))',
#  'and(and(one(plain,(2)),one(circle)),and(one(medium),one(high)))',
#  'and(and(two(striped,(0,1)),one(striped,(2))),and(two(unique,(0,2)),two(square,(0,2))))',
#  'and(and(two(plain,(0,2)),two(plain,(1,2))),and(two(circle,(0,1)),two(striped,(0,2))))',
#  'and(and(two(same),two(circle)),and(two(triangle),one(square)))',
#  'and(and(three(high),one(high)),and(two(2,unique),two(unique,(0,1))))',
#  'and(and(three(2,same),three(striped)),and(three(3,same),two(square,(1,2))))',
#  'and(and(one(plain,(2)),three(unique)),and(one(circle,(2)),two(unique,(0,1))))',
#  'and(and(two(striped,(1,2)),two(unique,(0,2))),and(three(1,unique),one(square,(0))))',
#  'and(and(three(unique),two(unique,(0,2))),two(1,unique))',
#  'and(and(one(medium,(1)),one(high,(1))),and(two(same),two(triangle,(0,2))))',
#  'and(and(two(square,(0,1)),one(low,(1))),and(two(same),two(low,(0,2))))',
#  'and(and(one(square,(2)),two(plain)),and(one(plain),two(medium,(1,2))))',
#  'and(and(one(low,(2)),two(circle,(0,2))),and(one(triangle),three(unique)))',
#  'and(and(two(triangle,(0,1)),one(striped,(1))),and(two(medium,(0,2)),three(2,unique)))',
#  'and(and(two(plain,(1,2)),two(striped,(1,2))),and(one(high),two(same)))',
#  'and(and(two(plain,(1,2)),two(high)),and(three(2,unique),two(medium,(1,2))))',
#  'and(and(two(plain,(1,2)),two(medium,(1,2))),and(one(high),two(same)))',
#  'and(and(one(plain,(0)),two(circle,(0,2))),and(two(circle,(0,1)),two(low,(0,2))))',
#  'and(and(two(square,(1,2)),one(low)),and(two(unique,(0,2)),two(unique)))',
#  'and(and(two(same,(0,2)),two(plain,(0,2))),and(two(plain,(0,1)),one(high,(1))))',
#  'and(and(one(circle),one(plain,(1))),and(one(striped,(2)),two(circle,(0,2))))',
#  'and(and(two(circle,(0,2)),three(high)),and(two(square),one(low)))',
#  'and(and(two(medium),two(striped)),and(three(medium),one(medium,(2))))',
#  'and(and(one(circle,(0)),three(circle)),and(one(striped,(0)),two(plain,(0,1))))',
#  'and(and(one(plain,(0)),two(low,(1,2))),and(three(triangle),three(plain)))',
#  'and(and(one(high,(2)),one(high)),and(three(same),two(striped)))',
#  'and(and(one(triangle),one(circle,(1))),and(two(low,(0,1)),three(high)))',
#  'and(and(one(circle,(1)),two(square,(0,1))),and(two(high,(1,2)),two(low)))',
#  'and(and(three(same),three(triangle)),and(two(medium,(0,1)),one(circle,(0))))',
#  'and(and(two(same,(0,2)),one(low,(2))),and(one(triangle,(1)),two(2,same)))',
#  'and(and(one(circle,(2)),one(circle)),and(two(3,unique),one(plain)))',
#  'and(and(one(triangle,(1)),two(square)),and(two(plain,(0,1)),three(low)))',
#  'and(and(three(3,unique),two(2,unique)),and(two(same),two(2,same)))',
#  'and(and(one(plain),two(high,(0,1))),and(three(striped),two(same,(0,1))))',
#  'and(and(one(plain),two(plain,(0,1))),and(one(high),two(unique)))',
#  'and(and(two(circle,(0,2)),two(triangle,(1,2))),and(two(circle,(0,2)),two(medium)))',
#  'and(and(two(low,(0,2)),two(medium,(0,2))),and(two(low,(0,2)),two(medium,(0,2))))',
#  'and(and(two(3,same),two(circle,(0,1))),and(one(striped,(0)),two(medium)))',
#  'and(and(three(2,same),one(circle,(0))),and(two(circle),two(low,(1,2))))',
#  'and(and(three(1,same),one(striped,(0))),and(two(circle,(0,2)),one(low)))',
#  'and(and(one(triangle,(0)),two(medium)),and(two(2,unique),one(striped,(0))))',
#  'and(and(two(plain,(1,2)),two(3,unique)),and(two(plain),two(low)))',
#  'and(and(three(medium),two(low,(0,2))),and(two(square),one(medium,(0))))',
#  'and(and(three(square),two(plain,(0,2))),and(one(medium,(1)),three(1,same)))',
#  'and(and(two(medium,(0,2)),one(striped,(0))),and(one(plain,(2)),two(same,(0,1))))',
#  'and(and(two(high),three(square)),and(one(low,(2)),one(circle,(2))))',
#  'and(and(one(square,(0)),two(medium,(0,1))),and(two(unique,(0,2)),three(1,unique)))',
#  'and(and(three(triangle),two(circle,(1,2))),and(two(2,unique),three(2,unique)))',
#  'and(and(one(low,(0)),two(low,(1,2))),and(two(high,(1,2)),three(2,same)))',
#  'and(and(two(high,(1,2)),three(unique)),and(three(striped),one(plain,(0))))',
#  'and(and(one(low,(2)),two(low)),and(one(striped,(2)),two(triangle,(0,1))))',
#  'and(and(two(low,(1,2)),two(circle,(1,2))),and(two(square),two(high,(0,1))))',
#  'and(and(two(triangle,(0,1)),two(plain)),and(two(medium,(0,2)),two(medium,(0,2))))',
#  'and(and(one(plain,(1)),three(3,same)),and(one(triangle),two(medium)))',
#  'and(and(one(plain,(2)),two(unique)),and(two(same,(0,2)),two(same,(0,1))))',
#  'and(and(two(circle,(1,2)),two(triangle,(1,2))),and(two(same),three(1,unique)))',
#  'and(and(two(high),one(plain,(0))),and(two(unique,(0,1)),two(square,(0,1))))',
#  'and(and(one(triangle,(1)),one(plain,(0))),and(two(high,(0,1)),two(same,(0,2))))',
#  'and(and(two(circle,(0,2)),two(same)),and(one(medium,(0)),three(low)))',
#  'and(and(two(medium,(0,1)),two(2,same)),and(one(low,(2)),two(unique,(0,2))))',
#  'and(and(two(medium),two(unique,(0,1))),and(two(plain,(0,2)),two(2,same)))',
#  'and(and(two(low,(0,1)),three(triangle)),and(two(same),two(2,same)))',
#  'and(and(two(triangle,(0,1)),one(medium,(0))),and(one(square,(2)),one(high,(0))))',
#  'and(and(two(same,(0,2)),one(medium,(1))),and(one(square),two(plain,(0,2))))',
#  'and(and(two(same,(0,1)),one(medium,(2))),and(one(striped,(2)),three(medium)))',
#  'and(and(two(plain,(1,2)),two(square)),and(three(1,same),two(unique,(0,2))))',
#  'and(and(two(high,(0,1)),one(square,(1))),and(two(triangle,(0,1)),two(same,(0,1))))',
#  'and(and(two(3,same),two(1,same)),and(three(2,same),three(plain)))',
#  'and(and(three(unique),one(striped,(0))),and(one(circle),two(medium)))',
#  'and(and(three(1,same),one(circle)),and(two(medium,(1,2)),three(2,same)))',
#  'and(and(two(triangle,(0,2)),three(plain)),and(two(same,(1,2)),two(plain)))',
#  'and(and(one(medium),two(low,(0,2))),and(two(striped),two(same)))',
#  'and(and(two(striped,(0,2)),two(unique,(0,1))),and(two(unique,(0,1)),one(plain,(2))))',
#  'and(and(two(high,(0,1)),two(striped,(0,2))),and(three(circle),one(medium,(1))))',
#  'and(and(two(same,(1,2)),one(high,(1))),and(two(circle,(0,2)),one(circle,(1))))',
#  'and(and(two(medium,(0,2)),three(2,same)),and(two(low,(0,1)),two(unique,(0,1))))',
#  'and(and(three(circle),one(high,(1))),and(three(striped),two(striped,(1,2))))',
#  'and(and(two(circle,(1,2)),two(striped,(0,1))),and(two(1,same),two(square,(0,1))))',
#  'and(and(two(same,(0,2)),two(plain,(0,1))),and(three(1,same),two(circle,(0,1))))',
#  'and(and(two(striped),three(square)),and(one(high,(1)),two(square)))',
#  'and(and(two(circle,(0,2)),two(striped,(1,2))),and(three(low),two(square)))',
#  'and(and(two(triangle,(0,1)),three(2,unique)),and(one(circle),two(square,(0,2))))',
#  'and(and(two(same,(0,2)),two(medium,(0,2))),and(two(2,unique),three(2,unique)))',
#  'and(and(two(unique,(0,2)),two(square,(1,2))),and(two(square,(0,2)),two(high,(0,2))))',
#  'and(and(two(high,(0,2)),two(plain,(0,2))),and(one(low,(1)),two(2,same)))',
#  'and(and(one(striped,(1)),two(medium,(0,2))),and(two(striped,(0,2)),two(square,(1,2))))',
#  'and(and(two(high,(0,2)),two(low)),and(one(medium,(2)),two(high,(0,2))))',
#  'and(and(two(same),three(1,same)),and(one(triangle,(0)),one(triangle)))',
#  'and(and(two(medium,(0,2)),one(square,(1))),and(two(low,(1,2)),three(circle)))',
#  'and(and(two(1,unique),two(unique,(0,1))),and(two(plain),two(1,same)))',
#  'and(and(three(same),two(square,(1,2))),and(one(striped,(2)),two(medium,(0,2))))',
#  'and(and(one(striped,(0)),one(square,(0))),and(one(medium,(2)),two(plain,(0,1))))',
#  'and(and(two(triangle),two(striped)),and(three(unique),two(low)))',
#  'and(and(three(square),two(striped)),and(two(medium),three(unique)))',
#  'and(and(two(unique,(1,2)),two(same)),and(three(1,same),two(plain,(0,1))))',
#  'and(and(one(striped),three(2,same)),and(two(same),one(triangle,(1))))',
#  'and(and(two(plain),two(triangle,(1,2))),and(two(square,(0,1)),two(unique,(0,2))))',
#  'and(and(two(circle,(0,1)),one(triangle,(0))),and(two(2,same),one(low)))',
#  'and(and(three(circle),two(circle)),and(two(same,(0,2)),two(circle,(0,2))))',
#  'and(and(two(striped,(0,2)),three(square)),and(three(3,same),one(plain,(2))))',
#  'and(and(two(high,(1,2)),three(plain)),and(two(plain,(0,1)),two(1,same)))',
#  'and(and(two(same,(0,2)),two(medium,(1,2))),and(three(triangle),two(triangle,(0,1))))',
#  'and(and(three(3,same),two(unique,(0,2))),and(two(triangle,(0,2)),two(striped,(0,1))))',
#  'and(and(two(1,unique),three(2,same)),and(one(circle,(1)),one(high,(2))))',
#  'and(and(one(square,(0)),one(triangle,(0))),and(two(striped,(0,2)),one(square)))',
#  'and(and(two(striped,(1,2)),one(square,(2))),and(one(square,(1)),two(3,unique)))',
#  'and(and(two(unique),one(high,(1))),and(one(circle,(2)),two(medium,(0,2))))',
#  'and(and(three(1,same),two(circle,(0,2))),and(two(striped,(0,1)),one(high,(2))))',
#  'and(and(one(high,(1)),one(circle,(0))),and(two(unique,(0,1)),two(same)))',
#  'and(and(three(medium),two(striped,(1,2))),and(one(medium,(0)),one(plain,(2))))',
#  'and(and(one(medium,(1)),two(circle,(1,2))),and(two(striped),two(1,same)))',
#  'and(and(three(3,unique),one(square)),and(two(3,unique),two(high,(0,1))))',
#  'and(and(two(square,(1,2)),one(triangle,(1))),and(two(triangle,(0,1)),two(low,(0,1))))',
#  'and(and(two(circle,(0,2)),one(circle,(1))),and(two(1,unique),one(medium,(1))))',
#  'and(and(one(plain,(0)),one(high,(0))),and(one(medium,(0)),one(circle)))',
#  'and(and(two(medium),two(circle,(0,2))),and(one(low,(0)),three(triangle)))',
#  'and(and(three(low),one(low,(1))),and(one(low),one(striped,(0))))',
#  'and(and(three(3,same),two(3,same)),and(two(square,(0,1)),two(1,unique)))',
#  'and(and(two(high,(0,1)),two(triangle)),and(one(square,(1)),one(circle,(1))))',
#  'and(and(two(plain),two(low,(0,1))),and(two(high,(0,2)),two(1,unique)))',
#  'and(and(two(plain),three(square)),two(low,(0,2)))',
#  'and(and(one(square,(2)),two(1,unique)),and(one(circle,(0)),two(square,(1,2))))',
#  'and(and(one(square,(1)),three(triangle)),and(two(triangle,(1,2)),one(plain,(1))))',
#  'and(and(three(low),three(circle)),and(one(triangle),two(low)))',
#  'and(and(two(striped),two(circle)),and(one(medium,(0)),one(low)))',
#  'and(and(two(medium),three(plain)),and(one(circle,(2)),one(square)))',
#  'and(and(one(square,(1)),one(high,(1))),and(two(unique,(1,2)),one(high,(2))))',
#  'and(and(one(circle,(2)),two(low,(1,2))),and(two(plain,(0,2)),one(striped,(2))))',
#  'and(and(two(medium),three(3,unique)),and(one(circle,(2)),one(square,(0))))',
#  'and(and(two(triangle),three(same)),and(one(striped,(1)),one(striped,(0))))',
#  'and(and(two(high,(0,2)),three(same)),and(two(same,(0,1)),three(3,unique)))',
#  'and(and(one(circle,(1)),one(striped)),and(two(same,(1,2)),three(high)))',
#  'and(and(two(2,unique),three(triangle)),and(two(triangle,(1,2)),one(plain,(0))))',
#  'and(and(two(low,(0,1)),one(low,(0))),and(two(triangle,(0,1)),two(circle)))',
#  'and(and(two(3,same),one(medium,(2))),and(one(circle,(0)),one(square,(0))))',
#  'and(and(two(plain,(1,2)),two(medium)),and(two(striped,(0,2)),one(striped,(2))))',
#  'and(and(three(medium),two(triangle,(1,2))),and(three(triangle),three(triangle)))',
#  'and(and(two(square),two(striped,(0,1))),and(one(low,(2)),two(square,(0,2))))',
#  'and(and(two(2,unique),two(circle,(1,2))),and(one(triangle,(0)),two(plain,(1,2))))',
#  'and(and(one(low,(0)),two(square)),and(two(same,(0,2)),three(circle)))',
#  'and(and(three(same),two(plain,(1,2))),and(three(3,same),two(plain,(0,2))))',
#  'and(and(one(square,(0)),one(medium,(2))),and(one(low,(2)),one(circle)))',
#  'and(and(two(same),three(circle)),and(one(triangle),three(unique)))',
#  'and(and(three(unique),two(triangle)),and(two(triangle,(1,2)),one(low,(0))))',
#  'and(and(one(square,(2)),one(plain,(1))),and(three(3,same),two(square,(0,1))))',
#  'and(and(two(unique,(1,2)),two(2,unique)),and(one(triangle,(0)),one(striped,(2))))',
#  'and(and(two(plain,(0,2)),two(triangle,(1,2))),and(two(medium,(0,1)),one(high,(2))))',
#  'and(and(two(medium,(0,1)),three(3,unique)),and(two(triangle,(0,2)),two(plain,(0,2))))',
#  'and(and(one(triangle,(2)),two(same,(0,1))),and(three(3,unique),one(plain,(0))))',
#  'and(and(two(striped,(0,2)),three(same)),and(two(high,(1,2)),two(circle)))',
#  'and(and(two(triangle,(0,2)),two(medium,(1,2))),and(one(triangle,(0)),one(high,(1))))',
#  'and(and(one(medium,(0)),three(square)),and(two(triangle,(0,1)),three(1,unique)))',
#  'and(and(one(square,(1)),two(high)),and(one(plain,(0)),three(square)))',
#  'and(and(three(square),one(striped,(1))),and(two(square,(0,2)),two(square,(1,2))))',
#  'and(and(two(high,(0,2)),two(triangle)),and(three(3,same),two(low,(1,2))))',
#  'and(and(one(circle,(2)),one(circle,(0))),and(one(square),two(plain,(1,2))))',
#  'and(and(two(striped),one(triangle)),and(one(plain,(2)),two(square,(0,1))))',
#  'and(and(three(3,same),two(plain)),and(two(same),two(low,(0,1))))',
#  'and(and(one(circle,(0)),two(striped,(1,2))),and(one(high,(2)),two(triangle,(0,1))))',
#  'and(and(one(medium),two(low,(0,2))),and(one(medium),one(high)))',
#  'and(and(two(same,(0,2)),two(striped,(1,2))),and(two(circle,(0,1)),two(circle,(0,2))))',
#  'and(and(one(medium,(2)),three(1,unique)),and(one(plain,(2)),one(circle,(1))))',
#  'and(and(one(circle,(1)),two(3,same)),and(one(square,(2)),one(square,(1))))',
#  'and(and(one(circle,(2)),one(medium,(0))),and(one(circle,(2)),two(2,unique)))',
#  'and(and(one(low,(1)),two(3,same)),and(two(2,unique),one(plain,(0))))',
#  'and(and(one(high,(2)),two(medium)),and(two(circle,(0,1)),two(low,(1,2))))',
#  'and(and(two(triangle,(0,2)),three(3,same)),and(three(high),one(plain,(2))))',
#  'and(and(three(1,same),three(same)),and(one(square),one(square)))',
#  'and(and(two(unique,(1,2)),one(low,(0))),and(one(medium,(1)),one(striped,(0))))',
#  'and(and(two(low,(0,2)),one(striped,(0))),and(two(striped,(1,2)),one(medium,(2))))',
#  'and(and(one(medium,(2)),two(high,(1,2))),and(one(square,(0)),one(medium,(0))))',
#  'and(and(three(striped),one(striped,(1))),and(two(striped,(0,1)),one(medium,(1))))',
#  'and(and(two(medium,(1,2)),one(square,(1))),and(two(striped,(1,2)),one(medium,(0))))',
#  'and(and(three(3,unique),two(triangle,(1,2))),and(two(2,unique),two(square,(1,2))))',
#  'and(and(two(plain,(0,1)),two(square,(1,2))),and(two(square),one(square)))',
#  'and(and(two(striped,(1,2)),one(circle,(1))),and(one(high,(1)),one(low,(2))))',
#  'and(and(two(medium,(0,2)),three(2,unique)),and(two(striped,(0,1)),two(same,(0,1))))',
#  'and(and(two(medium,(1,2)),two(high)),and(two(circle),one(plain,(0))))',
#  'and(and(one(triangle,(2)),two(low,(0,1))),and(one(circle,(2)),one(square,(0))))',
#  'and(and(three(circle),one(high,(0))),and(one(circle,(2)),two(plain)))',
#  'and(and(two(medium,(0,1)),three(2,same)),and(one(medium,(1)),two(same)))',
#  'and(and(two(unique,(0,1)),two(square)),and(two(unique),three(3,unique)))',
#  'and(and(two(2,same),one(high)),and(two(medium),two(medium,(0,2))))',
#  'and(and(one(high,(0)),one(triangle,(0))),and(two(medium),two(striped,(1,2))))',
#  'and(and(two(high,(0,1)),two(medium,(1,2))),and(two(unique,(1,2)),one(striped,(0))))',
#  'and(and(one(circle,(2)),one(triangle,(1))),and(two(circle,(1,2)),one(high,(1))))',
#  'and(and(three(triangle),two(high,(0,2))),and(three(2,unique),three(3,same)))',
#  'and(and(two(plain),three(2,unique)),and(one(low,(0)),two(same,(0,1))))',
#  'and(and(three(3,unique),two(medium,(0,2))),and(one(medium),two(medium,(1,2))))',
#  'and(and(three(striped),two(striped,(0,1))),and(one(square,(2)),one(plain)))',
#  'and(and(three(plain),one(low)),and(two(circle),two(striped,(0,2))))',
#  'and(and(one(striped,(1)),two(plain,(1,2))),and(one(medium,(0)),one(triangle,(2))))',
#  'and(and(two(medium,(0,2)),three(circle)),and(one(square,(0)),two(2,unique)))',
#  'and(three(2,unique),and(one(low,(1)),two(circle)))',
#  'and(and(one(plain,(1)),three(striped)),and(three(triangle),two(striped,(0,1))))',
#  'and(and(one(plain,(0)),one(square,(2))),and(two(medium,(1,2)),one(circle,(1))))',
#  'and(and(two(high),one(square,(0))),and(two(striped),two(low,(1,2))))',
#  'and(and(two(low,(0,1)),one(medium,(2))),and(three(unique),two(triangle,(0,2))))',
#  'and(and(two(low,(0,2)),one(striped)),and(three(medium),three(2,unique)))',
#  'and(and(two(triangle,(1,2)),two(plain,(0,1))),and(three(3,same),one(striped,(2))))',
#  'and(and(one(medium),two(circle,(0,1))),and(three(high),two(medium,(1,2))))',
#  'and(and(one(circle),one(square,(1))),and(two(same,(1,2)),two(medium)))',
#  'and(and(two(striped),three(medium)),and(two(low,(1,2)),two(2,same)))',
#  'and(and(two(unique),one(square)),and(three(plain),two(striped,(0,1))))',
#  'and(and(one(high,(0)),two(square,(0,1))),and(one(plain),two(medium,(0,1))))',
#  'and(and(two(triangle),two(same,(0,2))),and(three(medium),two(low,(0,1))))',
#  'and(and(one(triangle),two(same,(1,2))),and(one(square,(2)),two(same,(1,2))))',
#  'and(and(two(plain,(1,2)),three(3,same)),and(one(triangle,(2)),one(high,(2))))',
#  'and(and(two(high,(1,2)),one(triangle,(0))),and(one(plain,(2)),three(same)))',
#  'and(and(three(3,same),one(medium,(2))),and(two(striped),two(square,(1,2))))',
#  'and(and(three(square),two(high)),and(two(square,(0,1)),two(same)))',
#  'and(and(two(plain),two(square)),and(two(medium,(1,2)),three(triangle)))',
#  'and(and(two(high,(1,2)),two(low,(0,2))),and(one(striped,(2)),two(triangle,(0,1))))',
#  'and(and(two(medium,(0,2)),two(2,unique)),and(one(medium,(1)),three(3,unique)))',
#  'and(and(two(unique,(0,1)),three(1,unique)),and(one(square,(0)),two(square,(0,2))))',
#  'and(and(three(1,same),two(1,same)),and(two(circle,(1,2)),two(3,unique)))',
#  'and(and(one(striped,(0)),one(striped,(0))),and(two(plain,(0,2)),two(unique,(0,1))))',
#  'and(and(three(low),one(square,(1))),and(three(3,same),one(medium,(1))))',
#  'and(and(two(striped,(1,2)),one(striped)),and(three(striped),three(2,same)))',
#  'and(and(three(medium),three(3,unique)),and(three(unique),one(plain,(2))))',
#  'and(and(one(striped,(0)),one(medium,(2))),and(two(square,(1,2)),two(striped,(0,1))))',
#  'and(and(two(circle,(0,1)),one(plain)),and(one(medium,(2)),one(medium,(2))))',
#  'and(and(two(square,(0,1)),three(1,same)),and(two(striped,(1,2)),two(striped,(0,2))))',
#  'and(and(one(medium,(1)),one(high,(1))),and(one(plain,(1)),two(striped,(0,2))))',
#  'and(and(two(square,(0,2)),two(3,unique)),and(two(striped,(0,2)),two(high,(1,2))))',
#  'and(and(one(square,(0)),two(striped)),and(one(high,(0)),three(3,unique)))',
#  'and(and(two(1,same),three(high)),and(one(low,(1)),two(3,same)))',
#  'and(and(three(same),two(square,(0,2))),and(two(square),two(low,(1,2))))',
#  'and(and(one(low,(0)),two(high,(0,2))),and(two(low,(1,2)),one(circle,(0))))',
#  'and(and(one(striped,(2)),one(plain,(1))),and(one(striped,(2)),two(plain,(0,2))))',
#  'and(and(three(3,unique),two(triangle)),and(two(square,(1,2)),two(low,(1,2))))',
#  'and(and(two(2,unique),two(striped,(0,2))),and(two(unique),three(triangle)))',
#  'and(and(three(striped),two(high)),and(two(unique),one(high,(1))))',
#  'and(and(two(low,(1,2)),one(low,(1))),and(one(low,(0)),two(high,(0,2))))',
#  'and(and(one(triangle,(2)),two(medium,(0,2))),and(one(medium,(2)),two(1,unique)))',
#  'and(and(one(square),two(high,(1,2))),and(two(same,(1,2)),one(square,(2))))',
#  'and(and(three(high),one(triangle,(0))),and(one(circle),two(circle,(1,2))))',
#  'and(and(one(triangle,(1)),one(medium,(0))),and(two(medium,(0,1)),two(unique,(0,2))))',
#  'and(and(one(low),two(3,same)),and(one(high),one(square)))',
#  'and(and(one(high,(2)),two(striped)),and(two(3,same),one(triangle)))',
#  'and(and(one(triangle,(1)),three(triangle)),and(two(high,(0,1)),two(2,same)))',
#  'and(and(three(3,same),two(unique,(1,2))),and(two(medium),two(low,(0,2))))',
#  'and(and(one(medium,(2)),two(unique,(1,2))),and(two(same,(0,2)),one(circle)))',
#  'and(and(two(low,(0,2)),one(square,(1))),two(unique,(1,2)))',
#  'and(and(one(high,(2)),one(square,(0))),and(two(1,unique),two(unique,(0,1))))',
#  'and(and(one(medium,(0)),two(high)),and(one(low,(0)),one(plain,(2))))',
#  'and(and(three(striped),two(plain,(1,2))),and(one(triangle,(1)),two(triangle,(0,1))))',
#  'and(and(one(circle,(2)),one(square,(2))),and(one(striped),two(plain)))',
#  'and(and(three(medium),two(same,(0,2))),and(two(striped,(0,2)),two(same,(0,2))))',
#  'and(and(one(medium,(2)),two(plain)),and(one(square),three(2,same)))',
#  'and(and(two(striped,(1,2)),two(circle,(0,2))),and(one(square,(1)),one(circle,(0))))',
#  'and(and(two(1,same),one(plain,(0))),and(three(1,same),one(medium,(2))))',
#  'and(and(one(square,(1)),two(plain)),and(two(plain),one(triangle,(2))))',
#  'and(and(two(unique,(1,2)),two(same,(0,1))),and(three(square),one(striped)))',
#  'and(and(one(square,(1)),one(plain,(1))),and(two(same,(0,2)),one(medium,(0))))',
#  'and(and(three(1,same),two(circle,(0,2))),and(one(low,(1)),one(triangle,(1))))',
#  'and(and(two(triangle,(0,2)),two(same,(0,2))),and(one(square),one(high)))',
#  'and(and(three(triangle),two(same)),and(two(striped,(0,2)),two(medium)))',
#  'and(and(one(high,(1)),two(triangle,(1,2))),and(one(striped,(2)),one(low,(1))))',
#  'and(and(two(plain,(0,2)),two(1,unique)),and(three(medium),one(medium)))',
#  'and(and(one(high),one(square,(1))),and(two(same,(1,2)),one(low,(2))))',
#  'and(and(two(high),three(plain)),and(two(triangle,(0,2)),two(plain,(0,1))))',
#  'and(and(one(triangle,(0)),two(medium,(0,2))),and(two(1,unique),one(high,(2))))',
#  'and(and(two(medium,(0,1)),two(3,unique)),and(two(unique),one(high,(2))))',
#  'and(and(two(plain),two(medium,(1,2))),and(two(unique,(1,2)),one(plain)))',
#  'and(and(three(plain),two(1,same)),and(three(square),three(3,same)))',
#  'and(and(two(unique,(1,2)),two(same,(0,2))),and(two(1,unique),two(same,(0,1))))',
#  'and(and(one(circle),two(low,(1,2))),and(two(3,same),two(2,same)))',
#  'and(and(one(circle,(0)),one(high)),and(one(triangle,(2)),one(low)))',
#  'and(and(two(same,(0,1)),two(striped,(0,1))),and(two(medium),two(high,(0,1))))',
#  'and(and(two(square),two(square,(1,2))),and(two(striped,(1,2)),three(3,same)))',
#  'and(and(one(low,(0)),three(1,same)),and(two(unique,(1,2)),two(low,(1,2))))',
#  'and(and(one(triangle,(1)),two(square)),and(three(3,same),one(striped,(2))))',
#  'and(and(one(triangle,(1)),two(same,(1,2))),and(one(plain,(0)),two(same,(0,1))))',
#  'and(and(one(circle,(1)),two(unique,(0,2))),and(one(medium,(1)),two(square,(0,1))))',
#  'and(and(one(low),two(low,(0,1))),and(two(1,same),two(2,unique)))',
#  'and(and(two(plain,(1,2)),two(same,(0,2))),and(one(high,(2)),one(square)))',
#  'and(and(two(low,(1,2)),two(low)),and(two(same),one(high,(1))))',
#  'and(and(two(high,(0,2)),three(triangle)),and(two(circle,(0,1)),two(striped,(0,2))))',
#  'and(and(three(medium),two(circle,(1,2))),and(three(1,unique),one(medium)))',
#  'and(and(two(circle,(0,2)),one(striped,(2))),and(three(same),two(high)))',
#  'and(and(two(high,(0,1)),two(high,(0,1))),and(two(square),one(triangle,(1))))',
#  'and(and(two(3,same),two(circle,(1,2))),two(unique))',
#  'and(and(two(plain,(0,1)),two(2,same)),and(three(circle),one(high)))',
#  'and(and(two(striped,(0,2)),three(3,unique)),and(two(medium,(1,2)),one(striped,(1))))',
#  'and(and(two(striped,(0,1)),two(square,(0,2))),and(three(triangle),one(triangle,(0))))',
#  'and(and(one(square),two(low,(0,1))),and(two(square,(0,1)),two(1,unique)))',
# ...
#  'and(and(two(3,unique),two(medium,(0,1))),and(two(plain,(1,2)),two(same,(0,1))))',
#  'and(and(two(triangle,(0,1)),three(square)),and(one(high,(0)),two(high,(0,1))))',
#  'and(and(one(plain,(2)),three(triangle)),and(two(low,(0,2)),two(low,(1,2))))',
#  'and(and(two(unique,(1,2)),two(triangle)),and(one(striped,(1)),three(low)))',
#  'and(and(two(triangle,(0,2)),one(triangle)),and(two(plain,(0,1)),one(low)))',
#  'and(and(two(square),two(triangle,(0,2))),and(two(1,unique),two(striped,(1,2))))',
#  'and(and(two(unique,(0,1)),two(circle,(1,2))),and(two(same,(1,2)),one(plain,(1))))',
#  'and(and(one(circle,(0)),one(low)),and(two(medium,(0,2)),two(circle,(0,1))))',
#  'and(and(three(3,same),one(triangle)),and(two(unique,(1,2)),three(same)))',
#  'and(three(3,same),and(two(circle,(0,1)),one(plain,(2))))',
#  'and(and(two(medium,(0,2)),one(plain)),and(two(low,(0,2)),one(triangle,(1))))',
#  'and(and(one(medium),two(low,(0,2))),and(two(medium,(0,2)),one(high,(0))))',
#  'and(and(one(plain,(1)),three(1,same)),and(two(2,same),three(unique)))',
#  'and(and(one(plain,(1)),one(plain,(2))),and(three(2,same),one(plain)))',
#  'and(and(one(medium,(2)),two(plain,(0,2))),and(three(1,unique),two(striped,(1,2))))',
#  'and(and(three(2,same),two(square,(0,1))),and(one(high,(1)),one(plain,(0))))',
#  'and(and(two(high),one(medium)),and(two(1,same),one(low,(0))))',
#  'and(and(two(plain,(0,1)),one(triangle,(0))),and(two(low,(0,2)),one(plain,(1))))',
#  'and(and(two(square,(0,1)),two(square,(1,2))),and(two(1,same),two(square,(0,1))))',
#  'and(and(two(high,(0,2)),one(medium)),and(one(high,(2)),two(plain,(0,1))))',
#  'and(and(two(plain),two(1,unique)),and(one(low,(2)),two(striped)))',
#  'and(two(high,(0,1)),and(one(square),one(striped)))',
#  'and(and(two(medium,(0,2)),one(medium)),and(two(low),three(unique)))',
#  'and(and(two(triangle,(1,2)),one(triangle,(0))),and(one(circle,(1)),two(low,(0,1))))',
#  'and(and(one(striped),two(medium)),and(one(square,(0)),two(high,(0,1))))',
#  'and(and(two(low,(0,1)),one(circle,(1))),and(three(1,unique),two(low)))',
#  'and(and(two(circle,(1,2)),two(circle)),and(two(3,same),two(unique,(0,2))))',
#  'and(and(one(medium),three(striped)),and(one(high),three(high)))',
#  'and(and(two(striped),three(plain)),and(two(striped,(0,1)),two(low)))',
#  'and(and(two(same,(0,1)),two(low,(1,2))),and(three(unique),three(triangle)))',
#  'and(and(one(low,(1)),two(high,(0,1))),and(two(striped,(1,2)),two(medium)))',
#  'and(and(two(1,unique),two(medium,(0,1))),and(one(square,(0)),three(plain)))',
#  'and(and(one(high),one(triangle,(0))),and(two(circle,(0,1)),two(low,(0,1))))',
#  'and(and(two(unique,(0,2)),one(plain,(2))),and(one(triangle,(1)),two(low,(1,2))))',
#  'and(and(three(3,same),two(low,(1,2))),and(two(striped,(0,2)),one(triangle,(2))))',
#  'and(and(two(medium,(0,1)),one(triangle,(0))),and(two(high,(1,2)),one(circle,(0))))',
#  'and(and(three(circle),two(unique,(1,2))),and(two(medium,(1,2)),two(low,(0,2))))',
#  'and(and(three(3,unique),two(striped,(0,2))),and(one(low,(0)),one(medium,(1))))',
#  'and(and(one(low,(1)),one(high,(0))),and(two(medium,(0,1)),two(2,same)))',
#  'and(and(one(high,(0)),two(unique,(0,1))),and(two(3,same),two(circle,(0,2))))',
#  'and(and(two(triangle,(0,2)),three(unique)),and(two(same,(0,2)),two(3,same)))',
#  'and(and(one(striped,(2)),two(3,same)),and(one(plain,(2)),three(high)))',
#  'and(and(three(1,same),two(high,(1,2))),and(one(plain),three(circle)))',
#  'and(and(two(square,(0,1)),three(striped)),and(one(low,(0)),one(high,(1))))',
#  'and(and(two(striped,(0,1)),two(square)),and(two(triangle,(0,2)),one(plain,(1))))',
#  'and(and(two(triangle,(0,2)),two(high,(0,2))),and(two(square,(0,1)),two(square,(1,2))))',
#  'and(and(one(triangle),one(medium)),and(one(plain,(1)),two(high)))',
#  'and(and(three(2,unique),two(circle)),and(one(triangle,(0)),one(triangle,(1))))',
#  'and(and(two(unique,(0,2)),two(square,(1,2))),and(one(square,(2)),one(square)))',
#  'and(and(three(medium),one(triangle,(0))),and(two(triangle),two(high)))',
#  'and(and(two(striped,(0,1)),two(same)),and(two(square,(0,1)),two(medium,(0,1))))',
#  'and(and(two(plain,(0,1)),two(square)),and(one(square,(1)),three(plain)))',
#  'and(and(one(circle,(2)),one(triangle,(0))),and(three(medium),one(medium,(0))))',
#  'and(and(two(high,(0,2)),two(same,(0,2))),and(two(2,same),two(high,(0,1))))',
#  'and(and(three(1,same),one(triangle)),and(three(1,unique),two(same)))',
#  'and(and(two(same),two(unique,(0,2))),and(one(plain,(0)),two(striped)))',
#  'and(and(two(3,unique),three(1,unique)),and(two(circle),two(triangle,(0,2))))',
#  'and(and(two(square,(0,2)),one(high,(0))),and(two(2,same),three(3,unique)))',
#  'and(and(three(same),one(circle)),and(two(3,unique),two(circle,(0,2))))',
#  'and(and(one(triangle,(1)),two(striped)),and(one(striped,(2)),one(medium,(2))))',
#  'and(and(one(medium,(2)),two(3,same)),and(two(medium,(0,1)),two(3,same)))',
#  'and(and(three(plain),two(striped,(0,1))),and(two(triangle,(0,2)),two(plain,(0,1))))',
#  'and(and(two(high),two(plain)),and(two(high,(0,2)),one(square,(1))))',
#  'and(and(three(3,unique),three(triangle)),and(one(medium,(0)),two(3,same)))',
#  'and(and(two(circle,(0,1)),one(triangle,(2))),and(two(plain,(0,1)),one(triangle,(2))))',
#  'and(and(two(striped,(1,2)),one(medium,(1))),one(square,(2)))',
#  'and(and(two(high,(0,1)),three(2,same)),and(one(striped,(0)),two(circle,(1,2))))',
#  'and(and(one(high,(1)),three(unique)),and(two(square),two(low)))',
#  'and(and(two(square),two(medium,(0,1))),and(three(unique),three(1,same)))',
#  'and(and(one(high,(0)),one(circle,(1))),and(two(unique,(0,1)),two(striped)))',
#  'and(and(one(striped,(2)),one(striped)),and(one(triangle,(1)),two(square)))',
#  'and(and(one(high,(2)),two(plain,(1,2))),and(one(circle,(1)),two(medium,(0,1))))',
#  'and(and(one(low,(0)),two(triangle)),and(three(triangle),one(plain,(0))))',
#  'and(and(two(1,same),one(low,(0))),and(two(medium,(0,2)),one(high,(1))))',
#  'and(and(one(low,(0)),two(high)),and(two(triangle,(1,2)),three(triangle)))',
#  'and(and(three(3,unique),one(striped,(2))),and(one(high,(1)),one(medium,(0))))',
#  'and(and(one(medium,(1)),two(high,(0,2))),and(one(square,(1)),three(same)))',
#  'and(and(one(striped,(1)),two(medium,(1,2))),and(two(same,(0,2)),two(striped,(0,1))))',
#  'and(and(one(striped),two(3,same)),and(two(1,same),two(square,(1,2))))',
#  'and(and(three(circle),one(square,(1))),and(two(low,(1,2)),two(low,(1,2))))',
#  'and(and(three(unique),one(triangle)),and(one(striped,(1)),one(plain)))',
#  'and(and(one(plain,(1)),two(medium,(0,1))),and(two(unique,(0,1)),one(plain,(1))))',
#  'and(and(two(same),two(low,(1,2))),and(one(triangle,(2)),two(low)))',
#  'and(and(one(square,(2)),two(unique)),and(three(square),three(triangle)))',
#  'and(and(two(low,(0,2)),one(medium,(0))),and(two(striped,(0,2)),two(2,same)))',
#  'and(and(two(2,unique),one(circle,(2))),and(one(plain),two(plain,(0,2))))',
#  'and(and(one(low,(0)),one(high,(1))),and(one(square),one(plain,(2))))',
#  'and(and(three(plain),three(striped)),and(one(square,(2)),three(triangle)))',
#  'and(and(two(medium,(1,2)),two(unique,(1,2))),and(two(2,same),two(striped,(0,1))))',
#  'and(and(two(striped,(0,2)),three(3,same)),and(three(high),two(plain)))',
#  'and(and(one(plain,(2)),three(circle)),and(one(triangle,(2)),two(triangle,(1,2))))',
#  'and(and(two(triangle,(0,1)),three(circle)),and(three(striped),two(high,(0,1))))',
#  'and(and(two(unique,(1,2)),one(low,(2))),and(two(unique,(0,1)),two(striped)))',
#  'and(and(three(triangle),two(triangle,(0,2))),and(one(triangle),one(triangle,(2))))',
#  'and(and(three(striped),two(high,(0,2))),and(one(high,(0)),two(3,same)))',
#  'and(and(two(triangle,(1,2)),three(circle)),and(three(1,same),two(striped)))',
#  'and(and(two(2,same),three(2,same)),and(two(medium,(0,2)),two(unique,(0,2))))',
#  'and(and(two(square,(0,1)),two(striped,(0,1))),and(two(low),two(low,(0,1))))',
#  'and(and(one(high),one(triangle)),and(two(low,(1,2)),two(circle,(0,2))))',
#  'and(and(three(unique),one(high,(0))),and(two(unique,(0,2)),one(high,(1))))',
#  'and(and(two(same,(0,1)),two(medium)),and(two(circle,(0,2)),two(unique,(0,1))))',
#  'and(and(two(circle,(1,2)),two(triangle)),and(one(triangle,(1)),two(unique,(0,2))))',
#  'and(and(two(striped,(1,2)),one(circle)),and(one(medium,(1)),one(high,(2))))',
#  'and(and(two(square,(1,2)),two(high,(1,2))),and(one(high,(1)),two(triangle)))',
#  'and(and(two(high,(1,2)),two(high,(1,2))),and(two(striped),one(plain,(2))))',
#  'and(and(three(3,same),three(high)),and(two(plain,(0,2)),three(unique)))',
#  'and(and(two(same),one(triangle,(0))),and(two(same),one(high,(1))))',
#  'and(and(one(plain),two(1,same)),and(three(2,unique),two(circle)))',
#  'and(and(three(2,unique),two(square)),and(three(unique),one(striped,(2))))',
#  'and(and(two(unique,(0,1)),two(triangle)),one(plain,(1)))',
#  'and(and(two(same,(0,2)),one(circle,(1))),and(one(circle,(2)),three(3,same)))',
#  'and(and(one(circle,(1)),one(circle,(1))),and(one(triangle,(2)),one(low,(0))))',
#  'and(and(one(striped,(0)),three(unique)),and(one(triangle,(1)),three(plain)))',
#  'and(and(one(striped,(2)),one(low,(1))),and(three(3,unique),two(same)))',
#  'and(and(two(square,(1,2)),two(plain,(0,1))),and(two(square),one(high,(0))))',
#  'and(and(one(medium,(1)),one(plain,(0))),and(one(square),two(same,(0,2))))',
#  'and(and(two(medium,(1,2)),two(striped)),and(one(circle,(0)),two(low,(0,2))))',
#  'and(and(one(striped,(1)),two(low)),and(two(2,same),one(striped,(2))))',
#  'and(and(two(striped),two(circle,(0,2))),and(one(triangle),one(plain,(0))))',
#  'and(and(one(square,(0)),two(same)),and(three(same),one(high,(2))))',
#  'and(one(plain,(0)),and(three(plain),one(striped)))',
#  'and(and(two(triangle,(0,2)),two(high,(1,2))),and(two(striped,(0,2)),two(striped,(0,2))))',
#  'and(and(two(1,unique),two(triangle)),one(high,(1)))',
#  'and(and(three(striped),three(high)),and(one(circle,(2)),one(striped,(1))))',
#  'and(and(three(3,unique),two(1,same)),and(three(same),one(plain)))',
#  'and(and(one(square),one(striped,(0))),and(three(same),two(circle,(0,2))))',
#  'and(and(two(square,(0,2)),one(square,(1))),and(two(circle,(0,1)),one(high,(2))))',
#  'and(and(two(medium,(0,2)),three(2,unique)),and(three(plain),one(square,(1))))',
#  'and(and(three(plain),one(plain,(1))),and(two(unique,(1,2)),one(circle,(2))))',
#  'and(and(three(1,same),three(3,unique)),and(one(high,(1)),two(plain,(0,1))))',
#  'and(and(one(plain,(0)),one(circle)),and(two(square,(1,2)),two(1,unique)))',
#  'and(and(one(triangle,(0)),two(medium,(0,2))),and(one(medium,(0)),two(medium)))',
#  'and(and(two(high,(0,1)),two(square,(0,1))),and(two(2,same),three(low)))',
#  'and(and(two(plain),one(striped,(1))),and(one(triangle,(2)),two(triangle,(0,2))))',
#  'and(and(one(striped,(1)),two(low,(0,1))),and(one(high),two(striped)))',
#  'and(and(two(low,(0,1)),one(triangle,(2))),and(two(2,unique),two(square,(0,1))))',
#  'and(and(three(3,same),one(striped)),and(two(high,(0,2)),one(medium,(2))))',
#  'and(and(one(square),one(striped,(1))),and(two(1,same),two(3,unique)))',
#  'and(and(two(medium,(1,2)),two(triangle,(0,2))),and(two(square,(0,2)),one(circle)))',
#  'and(and(two(low),two(square,(0,2))),and(two(2,unique),three(plain)))',
#  'and(and(one(medium,(0)),one(medium,(2))),and(one(low,(1)),two(unique,(0,2))))',
#  'and(and(two(low,(0,2)),three(square)),and(two(plain,(0,2)),three(3,same)))',
#  'and(and(one(medium,(2)),one(low,(0))),and(three(same),one(plain,(2))))',
#  'and(and(two(plain,(0,1)),two(plain,(1,2))),and(two(medium,(1,2)),two(unique,(0,1))))',
#  'and(and(one(plain),three(3,unique)),and(one(circle,(0)),two(high,(0,1))))',
#  'and(and(two(high,(1,2)),two(1,same)),and(three(3,same),two(3,unique)))',
#  'and(and(three(circle),two(triangle,(0,1))),and(two(unique),two(medium)))',
#  'and(and(one(medium,(0)),two(unique)),and(two(medium,(0,2)),one(low,(1))))',
#  'and(and(one(low,(1)),two(square,(1,2))),and(three(triangle),two(plain)))',
#  'and(and(one(circle,(2)),one(high,(1))),and(two(3,unique),one(circle,(2))))',
#  'and(and(two(high,(0,1)),two(medium,(1,2))),and(three(1,same),two(high,(0,2))))',
#  'and(and(one(high,(0)),three(triangle)),and(one(medium,(2)),three(striped)))',
#  'and(and(three(medium),two(high,(1,2))),and(two(3,unique),two(unique,(0,1))))',
#  'and(and(one(medium,(1)),one(square,(0))),and(one(plain,(1)),two(unique,(0,2))))',
#  'and(and(one(low,(2)),two(square,(0,1))),two(unique))',
#  'and(and(two(1,same),two(1,same)),and(one(low,(2)),one(low,(1))))',
#  'and(and(two(3,unique),two(circle,(0,1))),and(two(same,(0,1)),two(low,(1,2))))',
#  'and(and(two(low),three(1,same)),and(two(high,(0,1)),two(unique,(1,2))))',
#  'and(and(one(square,(0)),three(high)),and(two(circle,(1,2)),one(high,(0))))',
#  'and(and(two(low),two(striped,(1,2))),and(one(circle,(2)),one(circle,(2))))',
#  'and(and(one(high,(0)),three(1,same)),and(one(plain,(2)),two(plain,(0,2))))',
#  'and(and(two(plain),two(same,(1,2))),two(1,same))',
#  'and(and(one(medium,(2)),two(triangle,(0,1))),and(one(plain),one(triangle,(0))))',
#  'and(and(two(triangle,(1,2)),two(high,(0,2))),and(two(same,(1,2)),two(square,(1,2))))',
#  'and(and(one(plain,(2)),two(unique,(0,1))),and(one(circle,(2)),three(3,unique)))',
#  'and(and(two(2,unique),two(unique)),and(two(striped,(1,2)),two(1,same)))',
#  'and(two(medium),and(one(high),two(circle,(0,2))))',
#  'and(and(one(circle,(1)),one(plain,(2))),and(two(medium,(1,2)),two(high)))',
#  'and(and(one(square,(0)),two(1,same)),and(two(1,same),two(unique,(0,1))))',
#  'and(and(three(medium),one(low,(1))),and(two(plain,(0,1)),two(plain,(1,2))))',
#  'and(and(one(circle,(1)),one(low,(0))),and(one(plain,(1)),one(plain,(2))))',
#  'and(and(three(striped),one(square)),and(one(high),two(same,(0,2))))',
#  'and(and(one(circle),one(circle,(1))),and(two(striped,(0,2)),two(plain,(1,2))))',
#  'and(and(one(circle,(2)),two(1,unique)),and(three(1,same),one(triangle,(2))))',
#  'and(and(two(same,(0,2)),two(medium,(0,1))),and(two(striped),two(plain,(1,2))))',
#  'and(and(one(high,(0)),two(circle,(0,1))),and(two(medium,(0,2)),one(high,(0))))',
#  'and(and(two(square,(0,2)),two(triangle)),and(two(unique,(1,2)),one(high)))',
#  'and(and(one(square,(0)),one(square,(0))),and(two(same),one(plain,(1))))',
#  'and(and(one(triangle,(1)),two(medium)),and(one(square,(1)),two(triangle,(1,2))))',
#  'and(and(one(low,(1)),three(3,same)),and(two(unique,(0,1)),two(plain,(0,1))))',
#  'and(and(three(square),one(triangle,(1))),and(two(high),three(circle)))',
#  'and(and(one(plain,(2)),three(square)),two(same))',
#  'and(and(one(plain),three(square)),and(two(unique),two(plain,(0,2))))',
#  'and(and(three(circle),one(low,(2))),and(two(circle,(0,2)),one(plain,(1))))',
#  'and(and(one(triangle,(0)),two(unique,(0,2))),and(three(striped),one(triangle,(0))))',
#  'and(and(one(low),one(low,(1))),and(three(high),two(same,(1,2))))',
#  'and(and(two(low,(0,2)),two(square,(0,1))),and(one(low,(1)),two(2,unique)))',
#  'and(and(three(same),two(1,same)),and(three(striped),two(triangle,(0,2))))',
#  'and(and(two(circle,(0,2)),one(plain,(0))),and(two(unique),one(striped,(0))))',
#  'and(and(one(plain,(1)),two(plain)),and(two(high,(0,1)),two(square,(1,2))))',
#  'and(and(one(low,(2)),two(square,(0,1))),and(three(3,unique),one(low)))',
#  'and(and(two(plain),three(striped)),and(three(2,unique),one(medium,(2))))',
#  'and(and(two(striped,(1,2)),two(striped,(0,2))),and(three(triangle),two(2,same)))',
#  'and(and(one(circle),two(circle)),and(one(circle,(0)),one(medium)))',
#  'and(and(one(square),one(medium,(2))),and(two(medium,(1,2)),one(medium)))',
#  'and(and(three(2,unique),two(triangle,(0,1))),and(three(same),two(square)))',
#  'and(and(one(plain),two(square,(0,2))),and(one(low,(1)),one(triangle,(0))))',
#  'and(and(one(circle,(0)),two(same,(0,1))),and(one(square,(2)),three(1,unique)))',
#  'and(and(two(striped,(0,2)),two(1,unique)),and(two(unique,(1,2)),two(1,unique)))',
#  'and(and(two(3,same),two(plain,(0,2))),and(two(square),two(3,same)))',
#  'and(and(two(2,unique),three(medium)),and(two(high),one(medium)))',
#  'and(and(two(medium,(0,1)),one(plain,(1))),and(two(high),three(same)))',
#  'and(and(two(striped,(0,2)),one(high,(2))),and(two(plain,(0,2)),one(triangle,(1))))',
#  'and(and(two(triangle),one(high,(1))),and(two(unique),two(medium,(0,1))))',
#  ...}
